# %%
import numpy as np
import matplotlib as plt
plt.rcdefaults()

# set the axes color glbally for all plots

plt.rcParams.update({'axes.facecolor':'white'})
N_test = [10,20,40,80,160,640]
h_test = [1/10,1/20,1/40,1/80,1/160,1/640]
log_h_test = np.log(h_test)
error = [0.0009288815447982453,
    

        0.00023437045178610166,
    
        5.8728243305517976e-05,
1.4690557719141747e-05,
3.6731709641579445e-06,
2.2959181925697028e-07
]
log_error = np.log(error)
import matplotlib.pyplot as plt

# %%
h_test
# Out:
# [0.1, 0.05, 0.025, 0.0125, 0.00625, 0.0015625]

# %%
# %precision 6
error
# Out:
# [0.000929, 0.000234, 0.000059, 0.000015, 0.000004, 0.000000]

# %%
chia = np.zeros(5)
for i in range(0, 4):
    chia[i] = error[i]/error[i+1]
chia
# Out:
# array([3.963305, 3.990762, 3.997686, 3.999421, 0.      ])

# %%
plt.xlabel("h")
plt.ylabel("error L2")
plt.plot(h_test,error, marker = 'o')
plt.plot()
# Out:
# []

# %%
plt.figure(figsize = (6,6))
plt.xlabel("log h")
plt.ylabel("log (error L2)")
plt.plot(log_h_test,log_error, marker = 'o')

# %%
plt.figure(figsize = (6,6))
plt.xlabel("log h")
plt.ylabel("log (error L2)")
x = np.linspace(-7,-2,20)
y = 2*x
plt.plot(x,y,label = 'y=2x')
plt.legend()
plt.plot(log_h_test,log_error, marker = 'o')
